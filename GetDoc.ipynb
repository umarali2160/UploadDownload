# %%
import pandas as pd
import base64
from IPython.display import display, HTML
def create_download_link( df, title = "Download CSV file", filename = "data.csv"):  
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

# %%
import pandas as pd
from tkinter import *
from tkinter.ttk import *
from tkinter.filedialog import askopenfile 

#Only takes CSV files
def UploadAction():
    file_path = askopenfile(mode='r', filetypes=[('Image Files', '*csv')])
    dataframe = pd.read_csv(file_path.name) 
    # insert functions below for df manipulation: 
    # dataframe = function_name(dataframe)
    print(dataframe.head())
    return dataframe

# %%
def main():
    root = Tk()

    root.title('Explorer')
    root.geometry("500x500")
    root.config(background = "white")

    upload_button = Button(root, 
        text="Upload File", 
        command=lambda:UploadAction()
        ).grid(row=0,column=1)

    df = UploadAction()
    root.mainloop()
    return df

# %%
if __name__ == "__main__":
    df = main()
create_download_link(df)
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2019-01-11  38.220001  38.424999  37.877499  38.072498  36.590542
# 1  2019-01-14  37.712502  37.817501  37.305000  37.500000  36.040325
# 2  2019-01-15  37.567501  38.347500  37.512501  38.267502  36.777958
# 3  2019-01-16  38.270000  38.970001  38.250000  38.735001  37.227253
# 4  2019-01-17  38.549999  39.415001  38.314999  38.965000  37.448299
#
#       Volume
# 0  108092800
# 1  129756800
# 2  114843600
# 3  122278800
# 4  119284800
# <a download="data.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>
